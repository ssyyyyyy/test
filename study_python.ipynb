# %% [markdown]
# # pytnon study
# 1. matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-3, 3, 50)
y1 = 2*x + 1
y2 = x**2

# %%
plt.figure()
plt.plot(x, y1)
plt.show()

# %%
plt.figure(num=1, figsize=(5, 10),)
plt.plot(x, y2)
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='-')

plt.savefig('C:\\pythonProject\\littlecode\\test.png')

# %%
plt.plot(x, y2)
plt.plot(x, y1, color='red', linewidth=1.0, linestyle='--')

# %%
plt.figure()
plt.plot(x, y2,color='yellow', linewidth=3.0, linestyle='-')
plt.plot(x, y1, color='red', linewidth=1.0, linestyle='--')
plt.xlim((-1, 2))
plt.ylim((-2, 3))
plt.xlabel('I am x')
plt.ylabel('I am y')
plt.show()

# %%
plt.figure()
plt.plot(x, y2,color='yellow', linewidth=3.0, linestyle='-')
plt.plot(x, y1, color='red', linewidth=1.0, linestyle='--')
plt.xlim((-1, 2))
plt.ylim((-2, 3))
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
new_ticks = np.linspace(-1, 2, 5)
plt.xlabel('I am x')
plt.ylabel('I am y')     
plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3],['$really\ bad$', '$bad$', '$normal$', '$good$', '$really\ good$'])

plt.show()

# %% [markdown]
# python在matplotlib assumes it is a sequence of y values, and automatically generates the x values for you. Since python ranges start with 0, the default x vector has the same length as y but starts with 0

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
#plot is a versatile function, and will take an arbitrary number of arguments. For example, to plot x versus y, you can write:

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis((0, 6, 0, 20))
plt.show()

# %% [markdown]
# The axis function in the example above takes a list of [xmin, xmax, ymin, ymax] and specifies the viewport of the axes.

# %% [markdown]
# you will use numpy arrays. In fact, all sequences are converted to numpy arrays internally. The example below illustrates plotting several lines with different format styles in one function call using arrays.

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
